# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# #Encoding

# %%
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)

df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %% [markdown]
# #modelin using sklearn

# %%
X = df.drop(['Car_Name','Selling_Price'], axis=1)
y = df['Selling_Price']

# %%
X
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           5.59       27000          0             0             0
# 1    2013           9.54       43000          1             0             0
# 2    2017           9.85        6900          0             0             0
# 3    2011           4.15        5200          0             0             0
# 4    2014           6.87       42450          1             0             0
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          11.60       33988          1             0             0
# 297  2015           5.90       60000          0             0             0
# 298  2009          11.00       87934          0             0             0
# 299  2017          12.50        9000          1             0             0
# 300  2016           5.90        5464          0             0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# #spliting the train and test dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (240, 7)
# (240,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (61, 7)
# (61,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# model evaluate
#
#
# **predicting on x_train**

# %%
prect_on_traing_data = model.predict(X_train)

# %%
from sklearn.metrics import r2_score
error_square=r2_score(y_train,prect_on_traing_data)
print('r square eror',error_square)
# Out:
# r square eror 0.8680830940612677

# %% [markdown]
# #visualize actual price and predicted prices

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(y_train,prect_on_traing_data)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %% [markdown]
# predicting on x_test

# %%
x_test_predict=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
error_square=r2_score(y_test,x_test_predict)
print('r square eror',error_square)
# Out:
# r square eror 0.9133788577647018

# %%
plt.scatter(y_test,x_test_predict)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()
