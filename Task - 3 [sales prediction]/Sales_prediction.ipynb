# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/Advertising.csv')
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
#create pairplot
sns.pairplot(df, x_vars=['TV', 'Radio', 'Newspaper'],
             y_vars='Sales', height=4,
             aspect=1, kind='scatter',
             plot_kws={'color': 'purple'})
plt.show()

# %% [markdown]
# *  Average expense spend highest on tv
# *  Average expense spend lowest on radio
# *  Max sale is 27 and min sale is 1.6

# %%
#modelling using sklearn
X = df[['TV','Radio','Newspaper']]
y = df[['Sales']]

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
#train test split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (160, 3)
# (160, 1)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (40, 3)
# (40, 1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
y_pred=model.fit(X_train, y_train)

# %% [markdown]
# #predicting on trained data

# %%
from sklearn import metrics
prect_on_training_data = model.predict(X_train)

# %%
from sklearn.metrics import r2_score
error_square=r2_score(y_train,prect_on_traing_data)
print('r square eror',error_square)
# Out:
# r square eror 0.8959372632325174

# %% [markdown]
# #predicting on test data

# %%
from sklearn import metrics
prect_on_testing_data = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
error_square=r2_score(y_test,prect_on_testing_data)
print('r square eror',error_square)
# Out:
# r square eror 0.8927605914615384
